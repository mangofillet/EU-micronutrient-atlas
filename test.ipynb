# %%
import pandas as pd

# %%
cd /home/jin/Documents/GITHUB/Food comparison by country/data
# Out:
# /home/jin/Documents/GITHUB/Food comparison by country/data

# %%
df = pd.read_csv("harmonized.csv")

# %%
df.head()
# Out:
#             food_name food_group country  n_matched  \
# 0           Beef, raw       Meat     USA         15
# 1           Beef, raw       Meat      UK         15
# 2           Beef, raw       Meat  Norway         15
# 3  Beef, minced (raw)       Meat     USA         15
# 4  Beef, minced (raw)       Meat      UK         15
#
#                                         sample_names  energy_kcal  protein_g  \
# 0  Beef, Eye of Round roast/steak, lean only, raw...          NaN     23.650
# 1  Beef, braising steak, raw, lean; Beef, braisin...          NaN        NaN
# 2  Beef patties, raw; Beef, chuck roll, raw; Beef...      183.267     19.247
# 3  Beef, Eye of Round roast/steak, lean only, raw...          NaN     23.400
# 4  Beef, braising steak, raw, lean; Beef, braisin...          NaN        NaN
#
#     fat_g  carbs_g  fiber_g  ...  folate_ug  vitamin_a_ug  vitamin_e_mg  \
# 0   2.562      NaN      NaN  ...        NaN           NaN           NaN
# ...
